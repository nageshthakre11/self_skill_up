# %%
import pandas as pd

# %%
pd.__version__      # to check available pandas version 
dir(pd)             # to check available functions in pandas
help(pd.read_csv)   # to get help about perticular function

# %%
df =  pd.read_csv("C:\\Users\\nthakre\\Desktop\\POC\\fhir\\skill_up\\olympics_1896_2004.csv", skiprows = 5)
df.head()
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
#
#    Event Event Gender   Medal  Position
# 0  100km            M    Gold         1
# 1  100km            M  Silver         2
# 2   100m            M  Bronze         3
# 3   100m            M  Bronze         3
# 4   100m            M    Gold         1

# %%
df.head(2)      # to get first 2 rows, by default 5 rows
df.tail(3)      # to get last 3 rows, by default 5 rows
df.sample(5)    # to get any sample 5 rows

# %%
df.info()  # to get details about columns, number of records, data types, not null details

# %%
df.describe()   # to get statistical data for analysis about quantitative columns

# %%
type(df)

# %%
df.columns

# %% [markdown]
# #### Select columns

# %%
df.Year                                         # dot operator
df.City 
df['Sport']                                     # square bracket
df['Athlete Name']
df[['Year','City', 'Sport','Medal']]            # to select multicolumn, df[list_of_columns] -> (df[[]])
type(df[['Year','City', 'Sport','Medal']])      # type of multi column selection is DataFrame
type(df['Sport'])                               # type of single column selection is - series
df['Sport'].unique()
df

# %%
df['Sport'].unique()
df['City'].unique()
df.Medal.value_counts()

# %%
# Q1. What is timerange of Data 
l = df.Year.unique()

# %%
# Q2. Where is the discontinuty in olympic games
for i in range(len(l)-1):
    d =  l[i+1] - l[i]
    if d != 4:
        print(l[i], l[i+1] )

# %%
# Q3. Which are the medal are awarded

df.Medal.unique()

# %%
# Q4. how many medal are awarded ?
df.Medal.value_counts()

# %%
df.sample(5)

# %%
df[['Medal','Gender']].value_counts()

# %% [markdown]
# #### Rename columns

# %%
df.sample(3)
df.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
#        'Event', 'Event Gender', 'Medal', 'Position'],
#       dtype='object')

# %%
mapper = {
        'Athlete Name' : 'Athlete_Name', 
        'Event Gender' : 'Event_Gender'
          }
df.rename(columns = mapper).columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete_Name', 'NOC', 'Gender',
#        'Event', 'Event_Gender', 'Medal', 'Position'],
#       dtype='object')

# %%
column_names = ['Year', 'City', 'Sport', 'Discipline', 'Athlete_Name', 'NOC', 'Gender',
       'Event', 'Event_Gender', 'Medal', 'Position']

df_renamed = pd.read_csv("C:\\Users\\nthakre\\Desktop\\POC\\fhir\\skill_up\\olympics_1896_2004.csv", skiprows = 5, names = column_names)
df_renamed.sample()
# Out:
#        Year    City     Sport Discipline     Athlete_Name  NOC Gender  \
# 12941  1972  Munich  Aquatics   Swimming  BEIER, Roswitha  GDR  Women
#
#                      Event Event_Gender   Medal Position
# 12941  4x100m medley relay            W  Silver        2

# %% [markdown]
# #### Remove Column

# %%
df.sample()
df.drop('Position', axis = 1)       # axis = 1 is for column 
df.drop([0, 2], axis = 0)           # droppend rows for index 0, 2 ; axis = 0 for rows
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# 5      1896  Athens  Athletics      Athletics      HOFMANN, Fritz  GER    Men
# 6      1896  Athens   Aquatics       Swimming       HAJOS, Alfred  HUN    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
# ...

# %% [markdown]
# #### Filter the records

# %%
df.sample()
df[df.Medal == 'Silver']
df[df.Year > 1900].head()
# Out:
#      Year      City      Sport       Discipline                 Athlete Name  \
# 663  1904  St Louis     Boxing           Boxing            MICHAELS, William
# 664  1904  St Louis     Boxing           Boxing               BERGER, Samuel
# 665  1904  St Louis     Boxing           Boxing               MAYER, Charles
# 666  1904  St Louis  Wrestling  Wrestling Free.  WARMBOLD, Frederick Charles
# 667  1904  St Louis  Wrestling  Wrestling Free.             HANSEN, Bernhuff
#
#      NOC Gender                    Event Event Gender   Medal  Position
# 663  USA    Men  + 71.67kg (heavyweight)            M  Silver         3
# 664  USA    Men  + 71.67kg (heavyweight)            M  Silver         1
# 665  USA    Men  + 71.67kg (heavyweight)            M  Silver         2
# 666  USA    Men  + 71.67kg (heavyweight)            M  Silver         3
# 667  USA    Men  + 71.67kg (heavyweight)            M  Silver         1

# %%
df[((df.Gender == 'Men') & (df.Sport == 'Boxing')) | (df.Gender == "Women")].value_counts
# Out:
# <bound method DataFrame.value_counts of        Year    City    Sport Discipline           Athlete Name  NOC Gender  \
# 464    1900   Paris     Golf       Golf           PRATT, Daria  USA  Women
# 465    1900   Paris     Golf       Golf  ABBOTT, Margaret Ives  USA  Women
# 466    1900   Paris     Golf       Golf      WHITTIER, Pauline  USA  Women
# 492    1900   Paris   Tennis     Tennis          JONES, Marion  ZZX  Women
# 493    1900   Paris   Tennis     Tennis      ROSENBAUM, Hedwig  ZZX  Women
# ...     ...     ...      ...        ...                    ...  ...    ...
# 27169  2004  Athens  Fencing    Fencing     LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens  Fencing    Fencing          SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens  Fencing    Fencing         BOKEL, Claudia  GER  Women
# 27172  2004  Athens  Fencing    Fencing        DUPLITZER, Imke  GER  Women
# 27173  2004  Athens  Fencing    Fencing      HEIDEMANN, Britta  GER  Women
#
# ...
